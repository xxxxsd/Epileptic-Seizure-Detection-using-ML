# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-5cfd0b02-1ce5-4cd4-9384-8f8f6c941f85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5cfd0b02-1ce5-4cd4-9384-8f8f6c941f85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Epileptic Seizure Recognition.csv to Epileptic Seizure Recognition.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Epileptic Seizure Recognition.csv")
 
df.head(20)
# Out:
#        Unnamed   X1   X2   X3   X4   X5  ...  X174  X175  X176  X177  X178  y
# 0   X21.V1.791  135  190  229  223  192  ...  -103  -127  -116   -83   -51  4
# 1   X15.V1.924  386  382  356  331  320  ...   157   156   154   143   129  1
# 2      X8.V1.1  -32  -39  -47  -37  -32  ...   -12   -30   -35   -35   -36  5
# 3    X16.V1.60 -105 -101  -96  -92  -89  ...   -85   -77   -72   -69   -65  5
# 4    X20.V1.54   -9  -65  -98 -102  -78  ...   -41   -65   -83   -89   -73  5
# 5    X14.V1.56   55   28   18   16   16  ...   -60   -64   -60   -56   -55  5
# 6    X3.V1.191  -55   -9   52  111  135  ...   -41   -26    11    67   128  4
# 7   X11.V1.273    1   -2   -8  -11  -12  ...   -76   -72   -66   -57   -39  2
# 8   X19.V1.874 -278 -246 -215 -191 -177  ...  -226  -174  -125   -79   -40  1
# 9    X3.V1.491    8   15   13    3   -6  ...   -17   -19   -15   -15   -11  4
# 10     X3.V1.6   -5   15   28   28    9  ...   -16   -74  -101   -89   -49  5
# 11  X21.V1.724 -167 -230 -280 -315 -338  ...   319   268   215   165   103  1
# 12   X7.V1.162   92   49    0  -32  -51  ...   -32   -13    -1    -7   -44  3
# 13   X1.V1.211   15   12    0  -17  -28  ...   -45   -19    13    44    68  4
# 14   X1.V1.615  -24  -15   -5   -1    4  ...    32    26    23    18    20  2
# 15  X22.V1.242 -135 -133 -125 -118 -111  ...   -10     4    21    31    37  3
# 16   X1.V1.863   39   41   41   42   43  ...    43    40    41    41    49  2
# 17   X9.V1.302    9    4   -5  -10  -22  ...    15    13     9     9     3  3
# 18   X7.V1.541  -21   -5    1    7   19  ...    30    35    26     5   -13  4
# 19   X9.V1.915    4   24   51   76   92  ...    31    36    40    43    36  2
#
# [20 rows x 180 columns]

# %%
cols = df.columns
tgt = df.y
tgt[tgt>1]=0
ax = sns.countplot(tgt,label="Count")
non_seizure, seizure = tgt.value_counts()
print('The number of trials for the non-seizure class is:', non_seizure)
print('The number of trials for the seizure class is:', seizure)
# Out:
# The number of trials for the non-seizure class is: 9200
# The number of trials for the seizure class is: 2300
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X = df.iloc[:,1:179].values
X.shape
# Out:
# (11500, 178)

# %%
plt.subplot(511)
plt.plot(X[1,:])
plt.title('Classes')
plt.ylabel('uV')
plt.subplot(512)
plt.plot(X[7,:])
plt.subplot(513)
plt.plot(X[12,:])
plt.subplot(514)
plt.plot(X[0,:])
plt.subplot(515)
plt.plot(X[2,:])
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, tgt, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units = 80, activation = 'relu', input_dim = 178))
classifier.add(Dense(units = 80, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
classifier.summary();
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 80)                14320
# _________________________________________________________________
# dense_1 (Dense)              (None, 80)                6480
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 81
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                160
# _________________________________________________________________
# dense_4 (Dense)              (None, 80)                6480
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 81
# _________________________________________________________________
# dense_6 (Dense)              (None, 80)                160
# _________________________________________________________________
# dense_7 (Dense)              (None, 80)                6480
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 81
# _________________________________________________________________
# dense_9 (Dense)              (None, 80)                160
# _________________________________________________________________
# dense_10 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 41,044
# Trainable params: 41,044
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

#Fitting the ANN to the training set
classifier.fit(X_train, y_train, batch_size = 10, epochs=100)
# Out:
# Epoch 1/100
# 920/920 [==============================] - 2s 1ms/step - loss: 0.3057 - accuracy: 0.9303
# Epoch 2/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0730 - accuracy: 0.9759
# Epoch 3/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0630 - accuracy: 0.9794
# Epoch 4/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0518 - accuracy: 0.9813
# Epoch 5/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0429 - accuracy: 0.9864
# Epoch 6/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0394 - accuracy: 0.9854
# Epoch 7/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0301 - accuracy: 0.9894
# Epoch 8/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0309 - accuracy: 0.9888
# Epoch 9/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0314 - accuracy: 0.9893
# Epoch 10/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0217 - accuracy: 0.9925
# Epoch 11/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0221 - accuracy: 0.9921
# Epoch 12/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0216 - accuracy: 0.9922
# Epoch 13/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0244 - accuracy: 0.9924
# Epoch 14/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0128 - accuracy: 0.9954
# Epoch 15/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0208 - accuracy: 0.9930
# Epoch 16/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0119 - accuracy: 0.9956
# Epoch 17/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0118 - accuracy: 0.9956
# Epoch 18/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0126 - accuracy: 0.9958
# Epoch 19/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0166 - accuracy: 0.9951
# Epoch 20/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0086 - accuracy: 0.9966
# Epoch 21/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0099 - accuracy: 0.9965
# Epoch 22/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0105 - accuracy: 0.9961
# Epoch 23/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0147 - accuracy: 0.9944
# Epoch 24/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0077 - accuracy: 0.9967
# Epoch 25/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0174 - accuracy: 0.9959
# Epoch 26/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0099 - accuracy: 0.9963
# Epoch 27/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 28/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 29/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0085 - accuracy: 0.9970
# Epoch 30/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0023 - accuracy: 0.9997
# Epoch 31/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0056 - accuracy: 0.9986
# Epoch 32/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0111 - accuracy: 0.9968
# Epoch 33/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9991
# Epoch 34/100
# 920/920 [==============================] - 1s 1ms/step - loss: 7.6634e-04 - accuracy: 0.9998
# Epoch 35/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.4920e-04 - accuracy: 1.0000
# Epoch 36/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.3157e-04 - accuracy: 1.0000
# Epoch 37/100
# 920/920 [==============================] - 1s 1ms/step - loss: 3.5211e-05 - accuracy: 1.0000
# Epoch 38/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.3973e-05 - accuracy: 1.0000
# Epoch 39/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0092 - accuracy: 0.9983
# Epoch 40/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0176 - accuracy: 0.9942
# Epoch 41/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 42/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0016 - accuracy: 0.9999
# Epoch 43/100
# 920/920 [==============================] - 1s 1ms/step - loss: 4.5377e-04 - accuracy: 0.9999
# Epoch 44/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0142 - accuracy: 0.9967
# Epoch 45/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0128 - accuracy: 0.9969
# Epoch 46/100
# 920/920 [==============================] - 1s 1ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 47/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.3381e-04 - accuracy: 1.0000
# Epoch 48/100
# 920/920 [==============================] - 1s 1ms/step - loss: 7.8037e-05 - accuracy: 1.0000
# Epoch 49/100
# 920/920 [==============================] - 1s 1ms/step - loss: 4.9334e-05 - accuracy: 1.0000
# Epoch 50/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.2756e-05 - accuracy: 1.0000
# Epoch 51/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.0355e-05 - accuracy: 1.0000
# Epoch 52/100
# 920/920 [==============================] - 1s 1ms/step - loss: 4.8942e-06 - accuracy: 1.0000
# Epoch 53/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.1310e-06 - accuracy: 1.0000
# Epoch 54/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.0874e-06 - accuracy: 1.0000
# Epoch 55/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.1053e-06 - accuracy: 1.0000
# Epoch 56/100
# 920/920 [==============================] - 1s 1ms/step - loss: 5.9993e-07 - accuracy: 1.0000
# Epoch 57/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.7798e-07 - accuracy: 1.0000
# Epoch 58/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.1517e-07 - accuracy: 1.0000
# Epoch 59/100
# 920/920 [==============================] - 1s 1ms/step - loss: 8.6810e-08 - accuracy: 1.0000
# Epoch 60/100
# 920/920 [==============================] - 1s 1ms/step - loss: 5.6016e-08 - accuracy: 1.0000
# Epoch 61/100
# 920/920 [==============================] - 1s 1ms/step - loss: 3.6297e-08 - accuracy: 1.0000
# Epoch 62/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.4217e-08 - accuracy: 1.0000
# Epoch 63/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.3405e-08 - accuracy: 1.0000
# Epoch 64/100
# 920/920 [==============================] - 1s 1ms/step - loss: 7.9971e-09 - accuracy: 1.0000
# Epoch 65/100
# 920/920 [==============================] - 1s 1ms/step - loss: 6.1645e-09 - accuracy: 1.0000
# Epoch 66/100
# 920/920 [==============================] - 1s 1ms/step - loss: 4.0099e-09 - accuracy: 1.0000
# Epoch 67/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.4086e-09 - accuracy: 1.0000
# Epoch 68/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.4367e-09 - accuracy: 1.0000
# Epoch 69/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.1231e-09 - accuracy: 1.0000
# Epoch 70/100
# 920/920 [==============================] - 1s 1ms/step - loss: 8.4166e-10 - accuracy: 1.0000
# Epoch 71/100
# 920/920 [==============================] - 1s 1ms/step - loss: 6.2110e-10 - accuracy: 1.0000
# Epoch 72/100
# 920/920 [==============================] - 1s 1ms/step - loss: 4.2782e-10 - accuracy: 1.0000
# Epoch 73/100
# 920/920 [==============================] - 1s 1ms/step - loss: 4.7468e-10 - accuracy: 1.0000
# Epoch 74/100
# 920/920 [==============================] - 1s 1ms/step - loss: 3.9921e-10 - accuracy: 1.0000
# Epoch 75/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.9959e-10 - accuracy: 1.0000
# Epoch 76/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.9278e-10 - accuracy: 1.0000
# Epoch 77/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.6121e-10 - accuracy: 1.0000
# Epoch 78/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.1215e-10 - accuracy: 1.0000
# Epoch 79/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.1440e-10 - accuracy: 1.0000
# Epoch 80/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.8449e-10 - accuracy: 1.0000
# Epoch 81/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.1280e-10 - accuracy: 1.0000
# Epoch 82/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.7681e-10 - accuracy: 1.0000
# Epoch 83/100
# 920/920 [==============================] - 1s 1ms/step - loss: 2.1896e-10 - accuracy: 1.0000
# Epoch 84/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.5795e-10 - accuracy: 1.0000
# Epoch 85/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.9245e-10 - accuracy: 1.0000
# Epoch 86/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.8376e-10 - accuracy: 1.0000
# Epoch 87/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.6861e-10 - accuracy: 1.0000
# Epoch 88/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.8246e-10 - accuracy: 1.0000
# Epoch 89/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.8968e-10 - accuracy: 1.0000
# Epoch 90/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.8611e-10 - accuracy: 1.0000
# Epoch 91/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.6336e-10 - accuracy: 1.0000
# Epoch 92/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.3937e-10 - accuracy: 1.0000
# Epoch 93/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.9308e-10 - accuracy: 1.0000
# Epoch 94/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.7424e-10 - accuracy: 1.0000
# Epoch 95/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.4358e-10 - accuracy: 1.0000
# Epoch 96/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.5413e-10 - accuracy: 1.0000
# Epoch 97/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.6626e-10 - accuracy: 1.0000
# Epoch 98/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.9428e-10 - accuracy: 1.0000
# Epoch 99/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.9359e-10 - accuracy: 1.0000
# Epoch 100/100
# 920/920 [==============================] - 1s 1ms/step - loss: 1.9465e-10 - accuracy: 1.0000

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
acc_ANN = classifier.evaluate(X_train, y_train)
# Out:
# 288/288 [==============================] - 0s 866us/step - loss: 1.4209e-10 - accuracy: 1.0000
